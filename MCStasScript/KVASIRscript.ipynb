# %%
import mcstasscript as ms

configurator = ms.Configurator()
configurator.set_mcrun_path("/Applications/McStas-3.2.app/Contents/Resources/mcstas/3.2/bin")
configurator.set_mcstas_path("/Applications/McStas-3.2.app/Contents/Resources/mcstas/3.2")

# %%
KVASIR = ms.McStas_instr("KVASIRscript")

Ef = KVASIR.add_parameter("Ef", comment="Ef [meV]")

d_AD = KVASIR.add_parameter("d_AD", comment="Distance from analyser to detector[m]")

d_SA = KVASIR.add_parameter("d_SA", comment="Distance from sample to analyser[m]")

# %%
# PARAMETERS
D_lambda= KVASIR.add_declare_var("double", "D_lambda", value=0.1)
width= KVASIR.add_declare_var("double", "width", value=0.001)
u = KVASIR.add_declare_var("double", "u", value=1E-4)
d_PG= KVASIR.add_declare_var("double", "d_PG", value=3.355)

lamda_f = KVASIR.add_declare_var("double", "lambda_f")
KVASIR.append_initialize("lambda_f=1/(0.11056*sqrt(Ef));")

tA = KVASIR.add_declare_var("double", "tA")
KVASIR.append_initialize("tA=asin(lambda_f/(2*d_PG))*RAD2DEG;")

tS= KVASIR.add_declare_var("double", "tS")
KVASIR.append_initialize("tS=0;")

d_SDz = KVASIR.add_declare_var("double", "d_SDz")
KVASIR.append_initialize("d_SDz=d_SA+d_AD*cos(2*tA*DEG2RAD);")

h_D = KVASIR.add_declare_var("double", "h_D")
KVASIR.append_initialize("h_D=d_AD*sin(2*tA*DEG2RAD);")

tRDx = KVASIR.add_declare_var("double", "tRDx")
KVASIR.append_initialize("tRDx=-RAD2DEG*atan(d_AD/d_SDz*sin(2*tA*DEG2RAD));")

tRDy = KVASIR.add_declare_var("double", "tRDy")
KVASIR.append_initialize("tRDy=360*0.0125/(2*d_SDz*3.142);")

d_SD = KVASIR.add_declare_var("double", "d_SD")
KVASIR.append_initialize("d_SD=d_AD*sin(2*tA*DEG2RAD)/sin(tRDx*DEG2RAD);")

# %%
origin = KVASIR.add_component("origin", "Progress_bar", AT=[0,0,0], RELATIVE="ABSOLUTE")

# %%
source = KVASIR.add_component("source", "Source_Maxwell_3", AT=[0,0,0], RELATIVE="PREVIOUS", ROTATED=["-tS",0,0], ROTATED_RELATIVE="origin")

source.xwidth=width
source.yheight=width
source.Lmin= "lambda_f-D_lambda/2"
source.Lmax= "lambda_f+D_lambda/2"
source.dist= d_SA
source.focus_yh=width
source.focus_xw=width
source.T1=300
source.T2=300
source.T3=300
source.I1=1E15
source.I2=1E15
source.I3=1E15

print(source)
# Out:
# COMPONENT source = Source_Maxwell_3(
#   yheight = width, // [m]
#   xwidth = width, // [m]
#   Lmin = lambda_f-D_lambda/2, // [AA]
#   Lmax = lambda_f+D_lambda/2, // [AA]
#   dist = d_SA, // [m]
#   focus_xw = width, // [m]
#   focus_yh = width, // [m]
#   T1 = 300, // [K]
#   T2 = 300, // [K]
#   T3 = 300, // [K]
#   I1 = 1000000000000000.0, // [1/(cm**2*st)]
#   I2 = 1000000000000000.0, // [1/(cm**2*st)]
#   I3 = 1000000000000000.0 // [1/(cm**2*st)]
# )
# AT (0, 0, 0) RELATIVE PREVIOUS
# ROTATED ('-tS', 0, 0) RELATIVE PREVIOUS

# %%
PSD_monitor_analyser = KVASIR.add_component("PSD_monitor_analyser", "PSD_monitor", AT=[0,0,"d_SA-u"], RELATIVE="PREVIOUS")

PSD_monitor_analyser.nx=40
PSD_monitor_analyser.ny = 40
PSD_monitor_analyser.xwidth = "width*2"
PSD_monitor_analyser.yheight = "width*2"
PSD_monitor_analyser.restore_neutron=1
PSD_monitor_analyser.filename='"PSD_analyzer.dat"'

# %%
Analyser = KVASIR.add_component("Analyzer","Monochromator_flat", AT = [0,0,0], RELATIVE="PREVIOUS", ROTATED=["90-tA",90,0], ROTATED_RELATIVE="PREVIOUS" )

Analyser.zwidth = "width*2"
Analyser.yheight = "width*2"
Analyser.mosaich = 37
Analyser.mosaicv = 37
Analyser.Q = 1.87278
Analyser.DM = d_PG
Analyser.r0 = 0.8

KVASIR.component_help("Monochromator_flat")
# Out:
#  ___ Help Monochromator_flat ________________________________________________________
# |optional parameter|required parameter|default value|user specified value|
# zmin = -0.05 [m] // Lower horizontal (z) bound of crystal
# zmax = 0.05 [m] // Upper horizontal (z) bound of crystal
# ymin = -0.05 [m] // Lower vertical (y) bound of crystal
# ymax = 0.05 [m] // Upper vertical (y) bound of crystal
# zwidth = 0.0 [m] // Width of crystal, instead of zmin and zmax
# yheight = 0.0 [m] // Height of crystal, instead of ymin and ymax
# mosaich = 30.0 [arc minutes] // Horizontal mosaic (in z direction) (FWHM)
# mosaicv = 30.0 [arc minutes] // Vertical mosaic (in y direction) (FWHM)
# r0 = 0.7 [1] // Maximum reflectivity
# Q = 1.8734 [1/angstrom] // Magnitude of scattering vector
# DM = 0.0 [AA] // monochromator d-spacing, instead of Q = 2*pi/DM
# -------------------------------------------------------------------------------------

# %%
N_detectors  = 15

for n in range(N_detectors):
    if n%2 == 0: #even number
        KVASIR.add_component(f"arm_detector_{int(n/2)}", "Arm", AT = [0,0,0], RELATIVE="source", ROTATED=[0,f"tRDy*{n/2}",0], ROTATED_RELATIVE="source")
        Detector = KVASIR.add_component(f"Detector_{int(n/2)}", "PSD_monitor", AT = [0,h_D, d_SDz], RELATIVE="PREVIOUS", ROTATED=[0,f"tRDy*{n/2}",0], ROTATED_RELATIVE="origin")
        Detector.nx = 40
        Detector.ny = 40
        Detector.xwidth = 0.0125
        Detector.yheight = 0.01
        Detector.restore_neutron=1
        Detector.filename=f'"Detector_{int(n/2)}.dat"'

        E_monitor = KVASIR.add_component(f"E_monitor_{int(n/2)}", "E_monitor", AT= [0,0,"u"], RELATIVE="PREVIOUS")
        E_monitor.xwidth = 0.0125
        E_monitor.yheight = 0.01
        E_monitor.Emin = 1.5
        E_monitor.Emax = 2.5
        E_monitor.restore_neutron = 1
        E_monitor.nE = 1000
        E_monitor.filename=f'"E_monitor_{int(n/2)}.dat"'
    if n%2 == 1: #odd number
        KVASIR.add_component(f"arm_detector_m{int((n+1)/2)}", "Arm", AT = [0,0,0], RELATIVE="source", ROTATED=[0,f"-tRDy*{(n+1)/2}",0], ROTATED_RELATIVE="source")
        Detector = KVASIR.add_component(f"Detector_m{int((n+1)/2)}", "PSD_monitor", AT = [0,h_D, d_SDz], RELATIVE="PREVIOUS", ROTATED=[0,f"-tRDy*{(n+1)/2}",0], ROTATED_RELATIVE="origin")
        Detector.nx = 40
        Detector.ny = 40
        Detector.xwidth = 0.0125
        Detector.yheight = 0.01
        Detector.restore_neutron=1
        Detector.filename=f'"Detector_m{int((n+1)/2)}.dat"'

        E_monitor = KVASIR.add_component(f"E_monitor_m{int((n+1)/2)}", "E_monitor", AT= [0,0,"u"], RELATIVE="PREVIOUS")
        E_monitor.xwidth = 0.0125
        E_monitor.yheight = 0.01
        E_monitor.Emin = 1.5
        E_monitor.Emax = 2.5
        E_monitor.restore_neutron = 1
        E_monitor.nE = 1000
        E_monitor.filename=f'"E_monitor_m{int((n+1)/2)}.dat"'

# %%
KVASIR.set_parameters(Ef=1.83, d_SA=3, d_AD=2)
KVASIR.show_parameters()
# Out:
#  Ef    = 1.83  // Ef [meV]
#  d_AD  = 2     // Distance from analyser to detector[m]
#  d_SA  = 3     // Distance from sample to analyser[m]

# %%
KVASIR.show_components()
# Out:
# origin               Progress_bar       AT      (0, 0, 0)         ABSOLUTE
# source               Source_Maxwell_3   AT      (0, 0, 0)         RELATIVE PREVIOUS
#                                         ROTATED (-tS, 0, 0)       RELATIVE PREVIOUS
# PSD_monitor_analyser PSD_monitor        AT      (0, 0, d_SA-u)    RELATIVE PREVIOUS
# Analyzer             Monochromator_flat AT      (0, 0, 0)         RELATIVE PREVIOUS
#                                         ROTATED (90-tA, 90, 0)    RELATIVE PREVIOUS
# arm_detector_0       Arm                AT      (0, 0, 0)         RELATIVE source
#                                         ROTATED (0, tRDy*0.0, 0)  RELATIVE source
# Detector_0           PSD_monitor        AT      (0, h_D, d_SDz)   RELATIVE PREVIOUS
#                                         ROTATED (0, tRDy*0.0, 0)  RELATIVE PREVIOUS
# E_monitor_0          E_monitor          AT      (0, 0, u)         RELATIVE PREVIOUS
# arm_detector_m1      Arm                AT      (0, 0, 0)         RELATIVE source
#                                         ROTATED (0, -tRDy*1.0, 0) RELATIVE source
# Detector_m1          PSD_monitor        AT      (0, h_D, d_SDz)   RELATIVE PREVIOUS
#                                         ROTATED (0, -tRDy*1.0, 0) RELATIVE PREVIOUS
# E_monitor_m1         E_monitor          AT      (0, 0, u)         RELATIVE PREVIOUS
# arm_detector_1       Arm                AT      (0, 0, 0)         RELATIVE source
#                                         ROTATED (0, tRDy*1.0, 0)  RELATIVE source
# Detector_1           PSD_monitor        AT      (0, h_D, d_SDz)   RELATIVE PREVIOUS
#                                         ROTATED (0, tRDy*1.0, 0)  RELATIVE PREVIOUS
# E_monitor_1          E_monitor          AT      (0, 0, u)         RELATIVE PREVIOUS
# arm_detector_m2      Arm                AT      (0, 0, 0)         RELATIVE source
#                                         ROTATED (0, -tRDy*2.0, 0) RELATIVE source
# Detector_m2          PSD_monitor        AT      (0, h_D, d_SDz)   RELATIVE PREVIOUS
#                                         ROTATED (0, -tRDy*2.0, 0) RELATIVE PREVIOUS
# E_monitor_m2         E_monitor          AT      (0, 0, u)         RELATIVE PREVIOUS
# arm_detector_2       Arm                AT      (0, 0, 0)         RELATIVE source
#                                         ROTATED (0, tRDy*2.0, 0)  RELATIVE source
# Detector_2           PSD_monitor        AT      (0, h_D, d_SDz)   RELATIVE PREVIOUS
#                                         ROTATED (0, tRDy*2.0, 0)  RELATIVE PREVIOUS
# E_monitor_2          E_monitor          AT      (0, 0, u)         RELATIVE PREVIOUS
# arm_detector_m3      Arm                AT      (0, 0, 0)         RELATIVE source
#                                         ROTATED (0, -tRDy*3.0, 0) RELATIVE source
# Detector_m3          PSD_monitor        AT      (0, h_D, d_SDz)   RELATIVE PREVIOUS
#                                         ROTATED (0, -tRDy*3.0, 0) RELATIVE PREVIOUS
# E_monitor_m3         E_monitor          AT      (0, 0, u)         RELATIVE PREVIOUS
# arm_detector_3       Arm                AT      (0, 0, 0)         RELATIVE source
#                                         ROTATED (0, tRDy*3.0, 0)  RELATIVE source
# Detector_3           PSD_monitor        AT      (0, h_D, d_SDz)   RELATIVE PREVIOUS
#                                         ROTATED (0, tRDy*3.0, 0)  RELATIVE PREVIOUS
# E_monitor_3          E_monitor          AT      (0, 0, u)         RELATIVE PREVIOUS
# arm_detector_m4      Arm                AT      (0, 0, 0)         RELATIVE source
#                                         ROTATED (0, -tRDy*4.0, 0) RELATIVE source
# Detector_m4          PSD_monitor        AT      (0, h_D, d_SDz)   RELATIVE PREVIOUS
#                                         ROTATED (0, -tRDy*4.0, 0) RELATIVE PREVIOUS
# E_monitor_m4         E_monitor          AT      (0, 0, u)         RELATIVE PREVIOUS
# arm_detector_4       Arm                AT      (0, 0, 0)         RELATIVE source
#                                         ROTATED (0, tRDy*4.0, 0)  RELATIVE source
# Detector_4           PSD_monitor        AT      (0, h_D, d_SDz)   RELATIVE PREVIOUS
#                                         ROTATED (0, tRDy*4.0, 0)  RELATIVE PREVIOUS
# E_monitor_4          E_monitor          AT      (0, 0, u)         RELATIVE PREVIOUS
# arm_detector_m5      Arm                AT      (0, 0, 0)         RELATIVE source
#                                         ROTATED (0, -tRDy*5.0, 0) RELATIVE source
# Detector_m5          PSD_monitor        AT      (0, h_D, d_SDz)   RELATIVE PREVIOUS
#                                         ROTATED (0, -tRDy*5.0, 0) RELATIVE PREVIOUS
# E_monitor_m5         E_monitor          AT      (0, 0, u)         RELATIVE PREVIOUS
# arm_detector_5       Arm                AT      (0, 0, 0)         RELATIVE source
#                                         ROTATED (0, tRDy*5.0, 0)  RELATIVE source
# Detector_5           PSD_monitor        AT      (0, h_D, d_SDz)   RELATIVE PREVIOUS
#                                         ROTATED (0, tRDy*5.0, 0)  RELATIVE PREVIOUS
# E_monitor_5          E_monitor          AT      (0, 0, u)         RELATIVE PREVIOUS
# arm_detector_m6      Arm                AT      (0, 0, 0)         RELATIVE source
#                                         ROTATED (0, -tRDy*6.0, 0) RELATIVE source
# Detector_m6          PSD_monitor        AT      (0, h_D, d_SDz)   RELATIVE PREVIOUS
#                                         ROTATED (0, -tRDy*6.0, 0) RELATIVE PREVIOUS
# E_monitor_m6         E_monitor          AT      (0, 0, u)         RELATIVE PREVIOUS
# arm_detector_6       Arm                AT      (0, 0, 0)         RELATIVE source
#                                         ROTATED (0, tRDy*6.0, 0)  RELATIVE source
# Detector_6           PSD_monitor        AT      (0, h_D, d_SDz)   RELATIVE PREVIOUS
#                                         ROTATED (0, tRDy*6.0, 0)  RELATIVE PREVIOUS
# E_monitor_6          E_monitor          AT      (0, 0, u)         RELATIVE PREVIOUS
# arm_detector_m7      Arm                AT      (0, 0, 0)         RELATIVE source
#                                         ROTATED (0, -tRDy*7.0, 0) RELATIVE source
# Detector_m7          PSD_monitor        AT      (0, h_D, d_SDz)   RELATIVE PREVIOUS
#                                         ROTATED (0, -tRDy*7.0, 0) RELATIVE PREVIOUS
# E_monitor_m7         E_monitor          AT      (0, 0, u)         RELATIVE PREVIOUS
# arm_detector_7       Arm                AT      (0, 0, 0)         RELATIVE source
#                                         ROTATED (0, tRDy*7.0, 0)  RELATIVE source
# Detector_7           PSD_monitor        AT      (0, h_D, d_SDz)   RELATIVE PREVIOUS
#                                         ROTATED (0, tRDy*7.0, 0)  RELATIVE PREVIOUS
# E_monitor_7          E_monitor          AT      (0, 0, u)         RELATIVE PREVIOUS

# %%
KVASIR.set_parameters(Ef=1.82,d_SA=3,d_AD=2)
data = KVASIR.backengine()
# Out:
# loading system configuration
# loading user configuration from /Users/amaliedavidsen/.mcstas/3.2/mccode_config.json
# INFO: Using directory: "/Users/amaliedavidsen/Documents/KVASIR/MCStasScript/KVASIRscript_8"
# INFO: Regenerating c-file: KVASIRscript.c
# CFLAGS=
#
# -----------------------------------------------------------
#
# Generating single GPU kernel or single CPU section layout:
#
# -----------------------------------------------------------
#
# Generating GPU/CPU -DFUNNEL layout:
#
# -----------------------------------------------------------
# INFO: Recompiling: ./KVASIRscript.out
# ./KVASIRscript.c:9066:48: warning: format string is not a string literal (potentially insecure) [-Wformat-security]
#   if (!strcmp(filename,"\0")) sprintf(filename,NAME_CURRENT_COMP);
#                                                ^~~~~~~~~~~~~~~~~
# ./KVASIRscript.c:622:27: note: expanded from macro 'NAME_CURRENT_COMP'
# #define NAME_CURRENT_COMP (_comp->_name)
#                           ^~~~~~~~~~~~~
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/secure/_stdio.h:47:56: note: expanded from macro 'sprintf'
#   __builtin___sprintf_chk (str, 0, __darwin_obsz(str), __VA_ARGS__)
#                                                        ^~~~~~~~~~~
# ./KVASIRscript.c:9066:48: note: treat the string as an argument to avoid this
#   if (!strcmp(filename,"\0")) sprintf(filename,NAME_CURRENT_COMP);
#                                                ^
#                                                "%s",
# ./KVASIRscript.c:622:27: note: expanded from macro 'NAME_CURRENT_COMP'
# #define NAME_CURRENT_COMP (_comp->_name)
#                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/secure/_stdio.h:47:56: note: expanded from macro 'sprintf'
#   __builtin___sprintf_chk (str, 0, __darwin_obsz(str), __VA_ARGS__)
#                                                        ^
# ./KVASIRscript.c:9180:48: warning: format string is not a string literal (potentially insecure) [-Wformat-security]
#   if (!strcmp(filename,"\0")) sprintf(filename,NAME_CURRENT_COMP);
#                                                ^~~~~~~~~~~~~~~~~
# ./KVASIRscript.c:622:27: note: expanded from macro 'NAME_CURRENT_COMP'
# #define NAME_CURRENT_COMP (_comp->_name)
#                           ^~~~~~~~~~~~~
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/secure/_stdio.h:47:56: note: expanded from macro 'sprintf'
#   __builtin___sprintf_chk (str, 0, __darwin_obsz(str), __VA_ARGS__)
#                                                        ^~~~~~~~~~~
# ./KVASIRscript.c:9180:48: note: treat the string as an argument to avoid this
#   if (!strcmp(filename,"\0")) sprintf(filename,NAME_CURRENT_COMP);
#                                                ^
#                                                "%s",
# ./KVASIRscript.c:622:27: note: expanded from macro 'NAME_CURRENT_COMP'
# #define NAME_CURRENT_COMP (_comp->_name)
#                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/secure/_stdio.h:47:56: note: expanded from macro 'sprintf'
#   __builtin___sprintf_chk (str, 0, __darwin_obsz(str), __VA_ARGS__)
#                                                        ^
# 2 warnings generated.
# [cctools-port]: generating fake signature for './KVASIRscript.out'
# INFO: ===
# [KVASIRscript] Initialize
# *** TRACE end ***
#
# Save [KVASIRscript]
# Detector: PSD_monitor_analyser_I=459.13 PSD_monitor_analyser_ERR=0.459231 PSD_monitor_analyser_N=1e+06 "PSD_analyzer.dat"
# Detector: Detector_0_I=0.657021 Detector_0_ERR=0.0173263 Detector_0_N=1438 "Detector_0.dat"
# Detector: E_monitor_0_I=0.657021 E_monitor_0_ERR=0.0173263 E_monitor_0_N=1438 "E_monitor_0.dat"
# <E> : 1.81989 meV , E-width : 0.000103608 meV
# Detector: Detector_m1_I=0.541611 Detector_m1_ERR=0.0157404 Detector_m1_N=1184 "Detector_m1.dat"
# Detector: E_monitor_m1_I=0.541152 E_monitor_m1_ERR=0.0157337 E_monitor_m1_N=1183 "E_monitor_m1.dat"
# <E> : 1.8199 meV , E-width : 0.000106142 meV
# Detector: Detector_1_I=0.533418 Detector_1_ERR=0.0156215 Detector_1_N=1166 "Detector_1.dat"
# Detector: E_monitor_1_I=0.533418 E_monitor_1_ERR=0.0156215 E_monitor_1_N=1166 "E_monitor_1.dat"
# <E> : 1.8199 meV , E-width : 0.000106134 meV
# Detector: Detector_m2_I=0.269597 Detector_m2_ERR=0.011118 Detector_m2_N=588 "Detector_m2.dat"
# Detector: E_monitor_m2_I=0.26914 E_monitor_m2_ERR=0.0111086 E_monitor_m2_N=587 "E_monitor_m2.dat"
# <E> : 1.81994 meV , E-width : 0.000109296 meV
# Detector: Detector_2_I=0.273743 Detector_2_ERR=0.0112036 Detector_2_N=597 "Detector_2.dat"
# Detector: E_monitor_2_I=0.272827 E_monitor_2_ERR=0.0111848 E_monitor_2_N=595 "E_monitor_2.dat"
# <E> : 1.81995 meV , E-width : 0.000109122 meV
# Detector: Detector_m3_I=0.086755 Detector_m3_ERR=0.0063105 Detector_m3_N=189 "Detector_m3.dat"
# Detector: E_monitor_m3_I=0.0867599 E_monitor_m3_ERR=0.00631085 E_monitor_m3_N=189 "E_monitor_m3.dat"
# <E> : 1.82003 meV , E-width : 0.000100204 meV
# Detector: Detector_3_I=0.0798665 Detector_3_ERR=0.00605467 Detector_3_N=174 "Detector_3.dat"
# Detector: E_monitor_3_I=0.0798665 E_monitor_3_ERR=0.00605467 E_monitor_3_N=174 "E_monitor_3.dat"
# <E> : 1.82003 meV , E-width : 0.000112256 meV
# Detector: Detector_m4_I=0.0137743 Detector_m4_ERR=0.00251484 Detector_m4_N=30 "Detector_m4.dat"
# Detector: E_monitor_m4_I=0.0137743 E_monitor_m4_ERR=0.00251484 E_monitor_m4_N=30 "E_monitor_m4.dat"
# <E> : 1.82013 meV , E-width : 0.00010931 meV
# Detector: Detector_4_I=0.0174474 Detector_4_ERR=0.00283035 Detector_4_N=38 "Detector_4.dat"
# Detector: E_monitor_4_I=0.0174474 E_monitor_4_ERR=0.00283035 E_monitor_4_N=38 "E_monitor_4.dat"
# <E> : 1.82013 meV , E-width : 0.000104645 meV
# Detector: Detector_m5_I=0.00229611 Detector_m5_ERR=0.00102685 Detector_m5_N=5 "Detector_m5.dat"
# Detector: E_monitor_m5_I=0.00229611 E_monitor_m5_ERR=0.00102685 E_monitor_m5_N=5 "E_monitor_m5.dat"
# <E> : 1.82026 meV , E-width : 0.000146703 meV
# Detector: Detector_5_I=0.00137785 Detector_5_ERR=0.0007955 Detector_5_N=3 "Detector_5.dat"
# Detector: E_monitor_5_I=0.00137785 E_monitor_5_ERR=0.0007955 E_monitor_5_N=3 "E_monitor_5.dat"
# <E> : 1.82036 meV , E-width : 1.99705e-05 meV
# Detector: Detector_m6_I=0 Detector_m6_ERR=0 Detector_m6_N=0 "Detector_m6.dat"
# Detector: E_monitor_m6_I=0 E_monitor_m6_ERR=0 E_monitor_m6_N=0 "E_monitor_m6.dat"
# Detector: Detector_6_I=0 Detector_6_ERR=0 Detector_6_N=0 "Detector_6.dat"
# Detector: E_monitor_6_I=0 E_monitor_6_ERR=0 E_monitor_6_N=0 "E_monitor_6.dat"
# Detector: Detector_m7_I=0 Detector_m7_ERR=0 Detector_m7_N=0 "Detector_m7.dat"
# Detector: E_monitor_m7_I=0 E_monitor_m7_ERR=0 E_monitor_m7_N=0 "E_monitor_m7.dat"
# Detector: Detector_7_I=0 Detector_7_ERR=0 Detector_7_N=0 "Detector_7.dat"
# Detector: E_monitor_7_I=0 E_monitor_7_ERR=0 E_monitor_7_N=0 "E_monitor_7.dat"
#
# Finally [KVASIRscript: /Users/amaliedavidsen/Documents/KVASIR/MCStasScript/KVASIRscript_8]. Time: 2 [s]
# INFO: Placing instr file copy KVASIRscript.instr in dataset /Users/amaliedavidsen/Documents/KVASIR/MCStasScript/KVASIRscript_8

# %%
ms.make_sub_plot(data)
